# %%
# %pip install spomato
# Out:
# ...
#   Obtaining dependency information for spomato from https://files.pythonhosted.org/packages/80/8a/09707090c7051e195b722ba144379a75425e9d0d535200837767f4f8b310/spomato-0.2.0-py3-none-any.whl.metadata
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import spotipy as sp
import spomato as smo

import os
from os.path import join, dirname
from dotenv import load_dotenv

dotenv_path = join('/Users/mlid/Desktop/SpringboardDS/sbGit/SpotifyCapstone', '.envA')
load_dotenv(dotenv_path)

from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.util as util

# %%
# Authorise
creds=load_dotenv
spCreds=SpotifyClientCredentials(creds)
cachedToken=util.prompt_for_user_token(spCreds,scope='user-library-read user-read-currently-playing')
spFy=sp.Spotify(cachedToken)


# spoti = sp.Spotify(auth_manager=sp1)
# token = util.prompt_for_user_token(spoti)
# sp.trace = False
# Out:
#                 You need to set your Spotify API credentials.
#                 You can do this by setting environment variables like so:
#
#                 export SPOTIPY_CLIENT_ID='your-spotify-client-id'
#                 export SPOTIPY_CLIENT_SECRET='your-spotify-client-secret'
#                 export SPOTIPY_REDIRECT_URI='your-app-redirect-url'
#
#                 Get your credentials at
#                     https://developer.spotify.com/my-applications
# ---------------------------------------------------------------------------
# SpotifyException                          Traceback (most recent call last)
# /Users/mlid/Desktop/SpringboardDS/sbGit/SpotifyCapstone/Untitled.ipynb Cell 4 line 4
#       <a href='vscode-notebook-cell:/Users/mlid/Desktop/SpringboardDS/sbGit/SpotifyCapstone/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> creds=load_dotenv
# ...

# %%
sA=spFy.current_user_playing_track()
print(sA.keys())
# print(sA.keys())
# print(sA['item'].keys())
# print(sA['item']['artists'][0]['name'],sA['item']['track'][0]['name'])
# Out:
# dict_keys(['timestamp', 'context', 'progress_ms', 'item', 'currently_playing_type', 'actions', 'is_playing'])

# %%
results = spFy.current_user_playing_track()
print(results['item']['name'])
# for idx, item in enumerate(results['items']):
#     track = item['track']
#     print(idx, track['artists'][0]['name'], " – ", track['name'])
# Out:
# Thoughts from a Balcony

# %%
tid=results['item']['id']

# %%
spFy.audio_analysis(tid)
# Out:
# {'meta': {'analyzer_version': '4.0.0',
#   'platform': 'Linux',
#   'detailed_status': 'OK',
#   'status_code': 0,
#   'timestamp': 1588824398,
#   'analysis_time': 45.9688,
#   'input_process': 'libvorbisfile L+R 44100->22050'},
#  'track': {'num_samples': 4096428,
#   'duration': 185.77905,
#   'sample_md5': '',
#   'offset_seconds': 0,
#   'window_seconds': 0,
#   'analysis_sample_rate': 22050,
#   'analysis_channels': 1,
#   'end_of_fade_in': 0.24422,
#   'start_of_fade_out': 181.54523,
#   'loudness': -6.153,
#   'tempo': 87.327,
#   'tempo_confidence': 0.04,
#   'time_signature': 4,
#   'time_signature_confidence': 1.0,
#   'key': 6,
#   'key_confidence': 0.291,
#   'mode': 1,
#   'mode_confidence': 0.366,
# ...
